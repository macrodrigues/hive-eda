# %%
from beem import Hive
from beem.discussions import Query, Discussions
from beem.comment import Comment
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
q = Query(limit=10, tag="")
d = Discussions()

# %%
# post list for selected query
iter = 10
posts = d.get_discussions('hot', q, limit=iter)

# %%
print(next(posts).keys())
# Out:
# dict_keys(['author', 'permlink', 'category', 'title', 'body', 'json_metadata', 'created', 'last_update', 'depth', 'children', 'last_payout', 'cashout_time', 'total_payout_value', 'curator_payout_value', 'pending_payout_value', 'promoted', 'replies', 'body_length', 'author_reputation', 'parent_author', 'parent_permlink', 'url', 'root_title', 'beneficiaries', 'max_accepted_payout', 'percent_hbd', 'post_id', 'net_rshares', 'active_votes', 'authorperm', 'tags', 'community'])

# %%
amount = 8
data = [
    {
        'ID': post['post_id'],
        'Author': post['author'],
        'Created': post['created'],
        'Title': post['title'],
        'Category': post['category'],
        'Reputation': post['author_reputation'],
        'Votes': len(post['active_votes']),
        'Body Length': post['body_length'],
        'Tags': post['tags'],
        'Replies': post['replies'],
        'Metadata': post['json_metadata'],
        'Pending payout value': post['pending_payout_value'].amount,
        'Community': post['community']} \
    for post in posts if post['pending_payout_value'].amount > amount ]

# %%
df = pd.DataFrame.from_dict(data)
df
# Out:
#           ID          Author                   Created  \
# 0  115908815   armandosodano 2022-08-21 15:32:12+00:00
# 1  115908364    aliento.love 2022-08-21 15:11:54+00:00
# 2  115908433         edicted 2022-08-21 15:15:21+00:00
# 3  115907768        kkarenmp 2022-08-21 14:46:48+00:00
# 4  115906884  taskmaster4450 2022-08-21 14:01:00+00:00
# 5  115907149          erikah 2022-08-21 14:14:00+00:00
# 6  115908365        parizoda 2022-08-21 15:11:54+00:00
# 7  115908351     bek-muradov 2022-08-21 15:10:54+00:00
# 8  115906369        yerf2712 2022-08-21 13:34:27+00:00
#
#                                                Title      Category  Depth  \
# 0                    Quiet bay - watercolor on paper   hive-193212      0
# 1          Aliento's Top 7 - Community Curation #008   hive-110011      0
# 2                                Downvotes Oh Noes!    hive-167922      0
# 3  [ESP//ENG] Popurri Norteño | Feria de Mariachi...         music      0
# 4  Cryptocurrency Evolution: Getting Aligned With...   hive-167922      0
# 5  Trying Out My New Pizza Trays And A Challenge ...   hive-120586      0
# 6                                   My kindergarten.       holiday      0
# 7                                  My family party!   introduction      0
# 8    Mi inscripción en el Reto-Morphosis.  [ESP-ENG]   hive-108642      0
#
#          Reputation  Votes                                               Tags  \
# 0   675228238799546     97  [art, painting, watercolor, nature, life, ita,...
# 1     7534259350105    143  [curation, curacion, communities, community, s...
# 2  1410774637895713    248            [palnet, vyb, proofofbrain, leofinance]
# 3   338132506965988     49  [music, musica, violin, cover, karenmanrique, ...
# 4  3221917501969860    681  [cryptocurrency, businesscycle, ctp, vyb, proo...
# 5   789311834310048    135  [pizza, recipe, foodie, neoxian, proofofbrain,...
# 6      351029716629     32                                          [holiday]
# 7      354016839102     40                                     [introduction]
# 8     2508099594162     62  [retometamorfosis, salud, cambiodevida, spanis...
#
#   Replies                                           Metadata  Children  \
# 0      []  {'tags': ['art', 'painting', 'watercolor', 'na...         4
# 1      []  {'app': 'peakd/2022.07.1', 'format': 'markdown...         0
# 2      []  {'app': 'leofinance/0.2', 'format': 'markdown'...         4
# 3      []  {'app': 'peakd/2022.07.1', 'format': 'markdown...         1
# 4      []  {'app': 'leofinance/0.2', 'format': 'markdown'...         9
# 5      []  {'app': 'peakd/2022.07.1', 'format': 'markdown...        14
# 6      []  {'image': ['https://images.ecency.com/DQmTR98M...         0
# 7      []  {'image': ['https://images.ecency.com/DQmdRjj8...         0
# 8      []  {'app': 'peakd/2022.07.1', 'format': 'markdown...         5
#
#    Pending payout value Community
# 0                33.599
# 1                34.184
# 2                30.502
# 3                36.323
# 4                56.417
# 5                38.328
# 6                16.109
# 7                16.241
# 8                44.069

# %%
df
# Out:
#           ID          Author                   Created  \
# 0  115908815   armandosodano 2022-08-21 15:32:12+00:00
# 1  115908364    aliento.love 2022-08-21 15:11:54+00:00
# 2  115908433         edicted 2022-08-21 15:15:21+00:00
# 3  115907768        kkarenmp 2022-08-21 14:46:48+00:00
# 4  115906884  taskmaster4450 2022-08-21 14:01:00+00:00
# 5  115907149          erikah 2022-08-21 14:14:00+00:00
# 6  115908365        parizoda 2022-08-21 15:11:54+00:00
# 7  115908351     bek-muradov 2022-08-21 15:10:54+00:00
# 8  115906369        yerf2712 2022-08-21 13:34:27+00:00
#
#                                                Title      Category  Depth  \
# 0                    Quiet bay - watercolor on paper   hive-193212      0
# 1          Aliento's Top 7 - Community Curation #008   hive-110011      0
# 2                                Downvotes Oh Noes!    hive-167922      0
# 3  [ESP//ENG] Popurri Norteño | Feria de Mariachi...         music      0
# 4  Cryptocurrency Evolution: Getting Aligned With...   hive-167922      0
# 5  Trying Out My New Pizza Trays And A Challenge ...   hive-120586      0
# 6                                   My kindergarten.       holiday      0
# 7                                  My family party!   introduction      0
# 8    Mi inscripción en el Reto-Morphosis.  [ESP-ENG]   hive-108642      0
#
#          Reputation  Votes                                               Tags  \
# 0   675228238799546     97  [art, painting, watercolor, nature, life, ita,...
# 1     7534259350105    143  [curation, curacion, communities, community, s...
# 2  1410774637895713    248            [palnet, vyb, proofofbrain, leofinance]
# 3   338132506965988     49  [music, musica, violin, cover, karenmanrique, ...
# 4  3221917501969860    681  [cryptocurrency, businesscycle, ctp, vyb, proo...
# 5   789311834310048    135  [pizza, recipe, foodie, neoxian, proofofbrain,...
# 6      351029716629     32                                          [holiday]
# 7      354016839102     40                                     [introduction]
# 8     2508099594162     62  [retometamorfosis, salud, cambiodevida, spanis...
#
#   Replies                                           Metadata  Children  \
# 0      []  {'tags': ['art', 'painting', 'watercolor', 'na...         4
# 1      []  {'app': 'peakd/2022.07.1', 'format': 'markdown...         0
# 2      []  {'app': 'leofinance/0.2', 'format': 'markdown'...         4
# 3      []  {'app': 'peakd/2022.07.1', 'format': 'markdown...         1
# 4      []  {'app': 'leofinance/0.2', 'format': 'markdown'...         9
# 5      []  {'app': 'peakd/2022.07.1', 'format': 'markdown...        14
# 6      []  {'image': ['https://images.ecency.com/DQmTR98M...         0
# 7      []  {'image': ['https://images.ecency.com/DQmdRjj8...         0
# 8      []  {'app': 'peakd/2022.07.1', 'format': 'markdown...         5
#
#    Pending payout value Community
# 0                33.599
# 1                34.184
# 2                30.502
# 3                36.323
# 4                56.417
# 5                38.328
# 6                16.109
# 7                16.241
# 8                44.069

# %%
df.columns

# %%
df
